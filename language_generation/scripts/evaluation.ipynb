# %%
# %reload_ext autoreload
# %autoreload 2
from jupyter_utils import get_iterate_results, show_significance, scatter_plot_comparation, get_comparation_cases,plot_context_length2performance,language_evaluate_mask_with_sig,get_results, plot_context_length2performance_all
import numpy as np

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-4_b8_pre10_a0.005_l20.5', dataset_name='Pereira', print_log=True, bert_metric=None, pre_str = '09_30_',file_name='test_greedy.json')
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-4_b8_pre10_a0.005_l20.5_shuffle', dataset_name='Pereira', print_log=True, bert_metric=None, pre_str = '09_30_',file_name='test_greedy.json')
show_significance(result_1, result_2)
print('acc is ', np.sum(np.array(result_1['valid_loss']) < np.array(result_2['valid_loss']))/len(result_1['valid_loss']))
# scatter_plot_comparation(result_1, result_2, metric = 'bert_scores')
# scatter_plot_comparation(result_1, result_2, metric = 'corpus_bleu_score_1')
# Out:
# P01:	../results/09_30_Pereira_P01_gpt2-xl_lr1e-4_b8_pre10_a0.005_l20.5/test_greedy.json
# corpus_bleu_score_1: 0.234 rouge_1: 0.215 rouge_l: 0.210 loss: 2.686
# M02:	../results/09_30_Pereira_M02_gpt2-xl_lr1e-4_b8_pre10_a0.005_l20.5/test_greedy.json
# corpus_bleu_score_1: 0.236 rouge_1: 0.221 rouge_l: 0.217 loss: 2.711
# M04:	../results/09_30_Pereira_M04_gpt2-xl_lr1e-4_b8_pre10_a0.005_l20.5/test_greedy.json
# corpus_bleu_score_1: 0.237 rouge_1: 0.225 rouge_l: 0.217 loss: 2.695
# M07:	../results/09_30_Pereira_M07_gpt2-xl_lr1e-4_b8_pre10_a0.005_l20.5/test_greedy.json
# corpus_bleu_score_1: 0.231 rouge_1: 0.215 rouge_l: 0.210 loss: 2.714
# M15:	../results/09_30_Pereira_M15_gpt2-xl_lr1e-4_b8_pre10_a0.005_l20.5/test_greedy.json
# corpus_bleu_score_1: 0.229 rouge_1: 0.213 rouge_l: 0.210 loss: 2.727
# corpus_bleu_score_1: 0.23329116968357472 rouge_1: 0.2180892103676914 rouge_l: 0.21298573437813945 valid_loss: 2.7065845334077183
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'llama-7b_lr1e-4_b8_pre10_a0.005_l20.5', dataset_name='Pereira', print_log=True, bert_metric=None, pre_str = '09_30_',file_name='test.json')
result_2 = get_iterate_results(base_path = '../results/', para_str = 'llama-7b_lr1e-4_b8_pre10_a0.005_l20.5_shuffle', dataset_name='Pereira', print_log=True, bert_metric=None, pre_str = '09_30_',file_name='test_length.json')
show_significance(result_1, result_2)
print('acc is ', np.sum(np.array(result_1['valid_loss']) < np.array(result_2['valid_loss']))/len(result_1['valid_loss']))
# Out:
# P01:	corpus_bleu_score_1: 0.198 rouge_1: 0.253 rouge_l: 0.253 loss: 2.736
# M02:	corpus_bleu_score_1: 0.206 rouge_1: 0.258 rouge_l: 0.256 loss: 2.807
# M04:	corpus_bleu_score_1: 0.216 rouge_1: 0.267 rouge_l: 0.265 loss: 2.770
# M07:	corpus_bleu_score_1: 0.211 rouge_1: 0.262 rouge_l: 0.260 loss: 2.762
# M15:	corpus_bleu_score_1: 0.188 rouge_1: 0.242 rouge_l: 0.241 loss: 2.968
# corpus_bleu_score_1: 0.20379320049532815 rouge_1: 0.25661333333333336 rouge_l: 0.2552190476190476 valid_loss: 2.808693887623194
# P01:	corpus_bleu_score_1: 0.091 rouge_1: 0.138 rouge_l: 0.138 loss: 4.322
# M02:	corpus_bleu_score_1: 0.118 rouge_1: 0.132 rouge_l: 0.132 loss: 4.244
# M04:	corpus_bleu_score_1: 0.117 rouge_1: 0.127 rouge_l: 0.127 loss: 4.252
# M07:	corpus_bleu_score_1: 0.073 rouge_1: 0.051 rouge_l: 0.051 loss: 5.759
# M15:	corpus_bleu_score_1: 0.117 rouge_1: 0.133 rouge_l: 0.133 loss: 4.099
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-medium_lr1e-4_b8_pre10_a0.005_l20.5', dataset_name='Pereira', print_log=True, bert_metric=None, pre_str = '09_30_',file_name='test.json')
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-medium_lr1e-4_b8_pre10_a0.005_l20.5_shuffle', dataset_name='Pereira', print_log=True, bert_metric=None, pre_str = '09_30_',file_name='test.json')
show_significance(result_1, result_2)
print('acc is ', np.sum(np.array(result_1['valid_loss']) < np.array(result_2['valid_loss']))/len(result_1['valid_loss']))

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'llama-7b_lr1e-4_b8_pre10_a0.005_l20.5', dataset_name='Pereira', print_log=True, bert_metric=None, pre_str = '09_30_',file_name='test_greedy.json')
result_2 = get_iterate_results(base_path = '../results/', para_str = 'llama-7b_lr1e-4_b8_pre10_a0.005_l20.5_shuffle', dataset_name='Pereira', print_log=True, bert_metric=None, pre_str = '09_30_',file_name='test_greedy.json')
show_significance(result_1, result_2)
print('acc is ', np.sum(np.array(result_1['valid_loss']) < np.array(result_2['valid_loss']))/len(result_1['valid_loss']))
# scatter_plot_comparation(result_1, result_2, metric = 'bert_scores')
# scatter_plot_comparation(result_1, result_2, metric = 'corpus_bleu_score_1')
# Out:
# P01:	corpus_bleu_score_1: 0.278 rouge_1: 0.278 rouge_l: 0.264 loss: 2.119
# M02:	corpus_bleu_score_1: 0.249 rouge_1: 0.249 rouge_l: 0.237 loss: 2.117
# M04:	corpus_bleu_score_1: 0.243 rouge_1: 0.247 rouge_l: 0.231 loss: 2.140
# M07:	corpus_bleu_score_1: 0.258 rouge_1: 0.251 rouge_l: 0.241 loss: 2.144
# M15:	corpus_bleu_score_1: 0.273 rouge_1: 0.273 rouge_l: 0.261 loss: 2.138
# corpus_bleu_score_1: 0.2601404873936743 rouge_1: 0.2594253566405465 rouge_l: 0.24698010849909585 valid_loss: 2.131684391533775
# P01:	corpus_bleu_score_1: 0.176 rouge_1: 0.172 rouge_l: 0.167 loss: 2.634
# M02:	corpus_bleu_score_1: 0.169 rouge_1: 0.165 rouge_l: 0.161 loss: 2.740
# M04:	corpus_bleu_score_1: 0.182 rouge_1: 0.177 rouge_l: 0.167 loss: 2.771
# M07:	corpus_bleu_score_1: 0.183 rouge_1: 0.181 rouge_l: 0.173 loss: 2.710
# M15:	corpus_bleu_score_1: 0.187 rouge_1: 0.185 rouge_l: 0.182 loss: 2.799
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-4_b8_pre10_a0.005_l20.5', dataset_name='Pereira', print_log=True, bert_metric=None, pre_str = '09_30_',file_name='test.json')
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-4_b8_pre10_a0.005_l20.5_shuffle', dataset_name='Pereira', print_log=True, bert_metric=None, pre_str = '09_30_',file_name='test.json')
show_significance(result_1, result_2)
print('acc is ', np.sum(np.array(result_1['valid_loss']) < np.array(result_2['valid_loss']))/len(result_1['valid_loss']))
# scatter_plot_comparation(result_1, result_2, metric = 'bert_scores')
# scatter_plot_comparation(result_1, result_2, metric = 'corpus_bleu_score_1')
# Out:
# P01:	corpus_bleu_score_1: 0.250 rouge_1: 0.256 rouge_l: 0.248 loss: 2.686
# M02:	corpus_bleu_score_1: 0.244 rouge_1: 0.245 rouge_l: 0.239 loss: 2.711
# M04:	corpus_bleu_score_1: 0.257 rouge_1: 0.265 rouge_l: 0.254 loss: 2.695
# M07:	corpus_bleu_score_1: 0.231 rouge_1: 0.240 rouge_l: 0.231 loss: 2.714
# M15:	corpus_bleu_score_1: 0.225 rouge_1: 0.229 rouge_l: 0.220 loss: 2.727
# corpus_bleu_score_1: 0.24141688129029898 rouge_1: 0.2466365280289331 rouge_l: 0.2383604581072936 valid_loss: 2.7065845508112685
# P01:	corpus_bleu_score_1: 0.214 rouge_1: 0.223 rouge_l: 0.212 loss: 2.884
# M02:	corpus_bleu_score_1: 0.207 rouge_1: 0.218 rouge_l: 0.208 loss: 2.892
# M04:	corpus_bleu_score_1: 0.210 rouge_1: 0.215 rouge_l: 0.208 loss: 2.965
# M07:	corpus_bleu_score_1: 0.220 rouge_1: 0.222 rouge_l: 0.215 loss: 2.933
# M15:	corpus_bleu_score_1: 0.208 rouge_1: 0.214 rouge_l: 0.207 loss: 2.929
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2_lr1e-4_b8_pre10_a0.005_l20.5', dataset_name='Pereira', print_log=True, bert_metric=None, pre_str = '09_30_',file_name='test.json')
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2_lr1e-4_b8_pre10_a0.005_l20.5_shuffle', dataset_name='Pereira', print_log=True, bert_metric=None, pre_str = '09_30_',file_name='test.json')
show_significance(result_1, result_2)
print('acc is ', np.sum(np.array(result_1['valid_loss']) < np.array(result_2['valid_loss']))/len(result_1['valid_loss']))
# scatter_plot_comparation(result_1, result_2, metric = 'bert_scores')
# scatter_plot_comparation(result_1, result_2, metric = 'corpus_bleu_score_1')
# Out:
# P01:	corpus_bleu_score_1: 0.138 rouge_1: 0.132 rouge_l: 0.129 loss: 4.227
# M02:	corpus_bleu_score_1: 0.137 rouge_1: 0.133 rouge_l: 0.133 loss: 4.259
# M04:	corpus_bleu_score_1: 0.142 rouge_1: 0.135 rouge_l: 0.135 loss: 4.241
# M07:	corpus_bleu_score_1: 0.158 rouge_1: 0.147 rouge_l: 0.146 loss: 4.204
# M15:	corpus_bleu_score_1: 0.145 rouge_1: 0.140 rouge_l: 0.138 loss: 4.264
# corpus_bleu_score_1: 0.1441398311018564 rouge_1: 0.1373658830620856 rouge_l: 0.13602973678923047 valid_loss: 4.239233068675431
# P01:	corpus_bleu_score_1: 0.134 rouge_1: 0.126 rouge_l: 0.124 loss: 4.634
# M02:	corpus_bleu_score_1: 0.135 rouge_1: 0.122 rouge_l: 0.122 loss: 4.711
# M04:	corpus_bleu_score_1: 0.130 rouge_1: 0.116 rouge_l: 0.116 loss: 4.892
# M07:	corpus_bleu_score_1: 0.125 rouge_1: 0.117 rouge_l: 0.115 loss: 4.847
# M15:	corpus_bleu_score_1: 0.135 rouge_1: 0.121 rouge_l: 0.120 loss: 4.798
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-large_lr1e-4_b8_pre10_a0.005_l20.5', dataset_name='Pereira', print_log=True, bert_metric=None, pre_str = '09_30_',file_name='test_greedy.json')
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-large_lr1e-4_b8_pre10_a0.005_l20.5_shuffle', dataset_name='Pereira', print_log=True, bert_metric=None, pre_str = '09_30_',file_name='test_greedy.json')
show_significance(result_1, result_2)
print('acc is ', np.sum(np.array(result_1['valid_loss']) < np.array(result_2['valid_loss']))/len(result_1['valid_loss']))
# scatter_plot_comparation(result_1, result_2, metric = 'bert_scores')
# scatter_plot_comparation(result_1, result_2, metric = 'corpus_bleu_score_1')
# Out:
# P01:	corpus_bleu_score_1: 0.224 rouge_1: 0.206 rouge_l: 0.202 loss: 2.810
# M02:	corpus_bleu_score_1: 0.227 rouge_1: 0.210 rouge_l: 0.207 loss: 2.809
# M04:	corpus_bleu_score_1: 0.223 rouge_1: 0.212 rouge_l: 0.203 loss: 2.816
# M07:	corpus_bleu_score_1: 0.227 rouge_1: 0.207 rouge_l: 0.203 loss: 2.827
# M15:	corpus_bleu_score_1: 0.220 rouge_1: 0.208 rouge_l: 0.202 loss: 2.819
# corpus_bleu_score_1: 0.22411081885765433 rouge_1: 0.2084910588708057 rouge_l: 0.20331725939320877 valid_loss: 2.81635380540719
# P01:	corpus_bleu_score_1: 0.199 rouge_1: 0.193 rouge_l: 0.186 loss: 2.978
# M02:	corpus_bleu_score_1: 0.209 rouge_1: 0.207 rouge_l: 0.200 loss: 2.998
# M04:	corpus_bleu_score_1: 0.205 rouge_1: 0.195 rouge_l: 0.188 loss: 3.050
# M07:	corpus_bleu_score_1: 0.209 rouge_1: 0.199 rouge_l: 0.196 loss: 3.010
# M15:	corpus_bleu_score_1: 0.204 rouge_1: 0.202 rouge_l: 0.195 loss: 2.994
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_tid1,2_n100', dataset_name='ds003020', print_log=True)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_random_tid1,2_n100', dataset_name='ds003020', print_log=True)
show_significance(result_1, result_2)
scatter_plot_comparation(result_1, result_2, metric = 'bert_scores')
scatter_plot_comparation(result_1, result_2, metric = 'corpus_bleu_score_1')
# Out:
# corpus_bleu_score_1: 0.13930173190501127 rouge_1: 0.16571515359140246 rouge_l: 0.158964946706821 valid_loss: 3.8986049600297012
# corpus_bleu_score_1: 0.13897828312520583 rouge_1: 0.16458073810736007 rouge_l: 0.15784970179968283 valid_loss: 3.8765022636479443
# corpus_bleu_score_1: 0.13930173190501127,0.13897828312520583,0.6770006829729978
# rouge_1: 0.16571515359140246, 0.16458073810736007, nan
# rouge_l: 0.158964946706821, 0.15784970179968283, nan
# valid_loss: 3.8986049600297012, 3.8765022636479443, nan
# bert_scores: 0.6107779145240784, 0.6104776859283447, nan
# bert_scores_part: nan, nan, nan
# /home/yzy/anaconda3/envs/torch/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/yzy/anaconda3/envs/torch/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'llama-7b_lr1e-5_tid1,2_b2', dataset_name='Pereira', print_log=True)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'llama-7b_lr1e-5_tid1,2_b2_random', dataset_name='Pereira', print_log=True)
show_significance(result_1, result_2)

# %%
plot_context_length2performance(result_1, result_2)

# %%
# investigating the length effect in the performance
# context length

plot_context_length2performance(result_1, result_2)
plot_context_length2performance(result_1, result_2, metric='corpus_bleu_score_1')

# %%
result_1 = get_iterate_results(base_path = '../../history/decoding0710/results/', para_str = 'gpt2-xl_lr1e-5', dataset_name='HP', print_log=True,)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_random', dataset_name='HP', print_log=True,)
show_significance(result_1, result_2)
scatter_plot_comparation(result_1, result_2, metric = 'bert_scores')
scatter_plot_comparation(result_1, result_2, metric = 'corpus_bleu_score_1')
plot_context_length2performance(result_1, result_2)
plot_context_length2performance(result_1, result_2, metric = 'corpus_bleu_score_1')
# Out:
# F:	corpus_bleu_score_1: 0.13670656605082834 rouge_1: 0.10588342440801457 rouge_l: 0.10561020036429872
# I:	corpus_bleu_score_1: 0.143554948391014 rouge_1: 0.11336976320582878 rouge_l: 0.11309653916211293
# J:	corpus_bleu_score_1: 0.13295342180588082 rouge_1: 0.10703096539162113 rouge_l: 0.1062112932604736
# H:	corpus_bleu_score_1: 0.13406019602740915 rouge_1: 0.1085063752276867 rouge_l: 0.10795992714025501
# K:	corpus_bleu_score_1: 0.13378610460577672 rouge_1: 0.10602914389799635 rouge_l: 0.10548269581056466
# L:	corpus_bleu_score_1: 0.1404302194466129 rouge_1: 0.10810564663023678 rouge_l: 0.10783242258652094
# M:	corpus_bleu_score_1: 0.13540159597536647 rouge_1: 0.11003642987249546 rouge_l: 0.1097632058287796
# N:	corpus_bleu_score_1: 0.13633359354670832 rouge_1: 0.10714025500910747 rouge_l: 0.10632058287795992
# corpus_bleu_score_1: 0.13665333073119956 rouge_1: 0.10826275045537341 rouge_l: 0.10778460837887067 valid_loss: 3.718340872716708
# ...

# %%
result_3 = get_iterate_results(base_path = '../../history/decoding0710/results/', para_str = 'gpt2-xl_lr1e-5_a0.1f0.25_random', dataset_name='HP', print_log=True,)
# Out:
# corpus_bleu_score_1: 0.13252060022551826 rouge_1: 0.0981785063752277 rouge_l: 0.09681238615664846 valid_loss: 3.6939127518831056

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_tid1,2', dataset_name='Pereira', print_log=True,bert_metric = 'bert_scores')
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_tid1,2_random', dataset_name='Pereira', print_log=True,bert_metric = 'bert_scores')
show_significance(result_1, result_2)
scatter_plot_comparation(result_1, result_2, metric = 'bert_scores')
scatter_plot_comparation(result_1, result_2, metric = 'corpus_bleu_score_1')
# Out:
# P01:	corpus_bleu_score_1: 0.20832380952380952 rouge_1: 0.20606666666666668 rouge_l: 0.19466666666666668
# M02:	corpus_bleu_score_1: 0.20589047619047618 rouge_1: 0.2006666666666667 rouge_l: 0.19266666666666668
# M04:	corpus_bleu_score_1: 0.1865238095238095 rouge_1: 0.17693333333333333 rouge_l: 0.17079999999999998
# M07:	corpus_bleu_score_1: 0.19700952380952377 rouge_1: 0.184 rouge_l: 0.17786666666666667
# M15:	corpus_bleu_score_1: 0.1946142857142857 rouge_1: 0.189 rouge_l: 0.18106666666666665
# corpus_bleu_score_1: 0.19847238095238096 rouge_1: 0.19133333333333336 rouge_l: 0.18341333333333334 valid_loss: 2.86970452337265
# P01:	corpus_bleu_score_1: 0.17871428571428571 rouge_1: 0.16266666666666665 rouge_l: 0.15673333333333334
# M02:	corpus_bleu_score_1: 0.17871428571428571 rouge_1: 0.16266666666666665 rouge_l: 0.15673333333333334
# M04:	corpus_bleu_score_1: 0.17871428571428571 rouge_1: 0.16266666666666665 rouge_l: 0.15673333333333334
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_tid1,2', dataset_name='Pereira', print_log=True,bert_metric = 'bert_scores',file_name='inference.json')
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_tid1,2_random', dataset_name='Pereira', print_log=True,bert_metric = 'bert_scores',file_name='inference.json')
show_significance(result_1, result_2)
scatter_plot_comparation(result_1, result_2, metric = 'bert_scores')
scatter_plot_comparation(result_1, result_2, metric = 'corpus_bleu_score_1')
# Out:
# P01:	corpus_bleu_score_1: 0.10734383019072014 rouge_1: 0.07239690134426977 rouge_l: 0.07079441026809447
# M02:	corpus_bleu_score_1: 0.12850670063588726 rouge_1: 0.09522480443533074 rouge_l: 0.09354256854256854
# M04:	corpus_bleu_score_1: 0.1244874410544267 rouge_1: 0.0906318827371459 rouge_l: 0.08894964684438368
# M07:	corpus_bleu_score_1: 0.1332904115200766 rouge_1: 0.09193817878028405 rouge_l: 0.08963127515759095
# M15:	corpus_bleu_score_1: 0.11242704135467195 rouge_1: 0.07466203387256018 rouge_l: 0.07288676236044657
# corpus_bleu_score_1: 0.12121108495115653 rouge_1: 0.08497076023391813 rouge_l: 0.08316093263461685 valid_loss: 4.810851040377951
# P01:	corpus_bleu_score_1: 0.12004449410760663 rouge_1: 0.0810663021189337 rouge_l: 0.08011506037821826
# M02:	dataset Pereira and parameters gpt2-xl_lr1e-5_tid1,2_random missing user M02
# corpus_bleu_score_1: 0.12004449410760663 rouge_1: 0.0810663021189337 rouge_l: 0.08011506037821826
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_tid1,2', dataset_name='Pereira', print_log=True,bert_metric = 'bert_scores',file_name='inference.json')
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_tid1,2_random', dataset_name='Pereira', print_log=True,bert_metric = 'bert_scores',file_name='inference.json')
# show_significance(result_1, result_2)
# scatter_plot_comparation(result_1, result_2, metric = 'bert_scores')
# scatter_plot_comparation(result_1, result_2, metric = 'corpus_bleu_score_1')
get_comparation_cases(result_2, result_1)
# Out:
# P01:	dataset Pereira and parameters gpt2-xl_lr1e-5_tid1,2 missing user P01
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_tid1,2', dataset_name='Pereira', print_log=True,bert_metric = 'bert_scores',file_name='inference.json')
#       2 result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_tid1,2_random', dataset_name='Pereira', print_log=True,bert_metric = 'bert_scores',file_name='inference.json')
#       3 # show_significance(result_1, result_2)
#       4 # scatter_plot_comparation(result_1, result_2, metric = 'bert_scores')
#       5 # scatter_plot_comparation(result_1, result_2, metric = 'corpus_bleu_score_1')
#
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_tid1,2', dataset_name='Pereira', print_log=True,bert_metric = 'bert_scores',file_name='inference.json')
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_tid1,2_random', dataset_name='Pereira', print_log=True,bert_metric = 'bert_scores',file_name='inference.json')
show_significance(result_1, result_2)
scatter_plot_comparation(result_1, result_2, metric = 'bert_scores')
scatter_plot_comparation(result_1, result_2, metric = 'corpus_bleu_score_1')
# Out:
# P01:	corpus_bleu_score_1: 0.10734383019072014 rouge_1: 0.07239690134426977 rouge_l: 0.07079441026809447
# M02:	corpus_bleu_score_1: 0.12850670063588726 rouge_1: 0.09522480443533074 rouge_l: 0.09354256854256854
# M04:	corpus_bleu_score_1: 0.1244874410544267 rouge_1: 0.0906318827371459 rouge_l: 0.08894964684438368
# M07:	corpus_bleu_score_1: 0.1332904115200766 rouge_1: 0.09193817878028405 rouge_l: 0.08963127515759095
# M15:	corpus_bleu_score_1: 0.11242704135467195 rouge_1: 0.07466203387256018 rouge_l: 0.07288676236044657
# corpus_bleu_score_1: 0.12121108495115653 rouge_1: 0.08497076023391813 rouge_l: 0.08316093263461685 valid_loss: 4.810851040377951
# P01:	corpus_bleu_score_1: 0.12004449410760663 rouge_1: 0.0810663021189337 rouge_l: 0.08011506037821826
# M02:	dataset Pereira and parameters gpt2-xl_lr1e-5_tid1,2_random missing user M02
# corpus_bleu_score_1: 0.12004449410760663 rouge_1: 0.0810663021189337 rouge_l: 0.08011506037821826
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_tid1,2_a0.1f0.25', dataset_name='Pereira', print_log=True,reload=True)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_tid1,2_a0.1f0.25_random', dataset_name='Pereira', print_log=True,reload=True)
show_significance(result_1, result_2)
scatter_plot_comparation(result_1, result_2, metric = 'bert_scores')
scatter_plot_comparation(result_1, result_2, metric = 'corpus_bleu_score_1')
# Out:
# P01:	corpus_bleu_score_1: 0.1850238095238095 rouge_1: 0.17713333333333334 rouge_l: 0.1736666666666667
# M02:	corpus_bleu_score_1: 0.17239523809523807 rouge_1: 0.16506666666666667 rouge_l: 0.15893333333333334
# M04:	corpus_bleu_score_1: 0.1810571428571429 rouge_1: 0.17493333333333333 rouge_l: 0.16913333333333333
# M07:	corpus_bleu_score_1: 0.17316666666666666 rouge_1: 0.16679999999999998 rouge_l: 0.163
# M15:	corpus_bleu_score_1: 0.17325238095238094 rouge_1: 0.1663333333333333 rouge_l: 0.16026666666666664
# corpus_bleu_score_1: 0.17697904761904762 rouge_1: 0.17005333333333333 rouge_l: 0.165 valid_loss: 3.0225192170619963
# P01:	corpus_bleu_score_1: 0.16787142857142856 rouge_1: 0.16166666666666665 rouge_l: 0.15766666666666665
# M02:	dataset Pereira and parameters gpt2-xl_lr1e-5_tid1,2_a0.1f0.25_random missing user M02
# corpus_bleu_score_1: 0.16787142857142856 rouge_1: 0.16166666666666665 rouge_l: 0.15766666666666665
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_tid1,2_a0.1f0.25', dataset_name='Pereira', print_log=True,file_name='inference1.0.json',bert_metric=None)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_tid1,2_a0.1f0.25_random', dataset_name='Pereira', print_log=True,file_name='inference1.0.json',bert_metric=None)
show_significance(result_1, result_2)
scatter_plot_comparation(result_1, result_2, metric = 'bert_scores')
scatter_plot_comparation(result_1, result_2, metric = 'corpus_bleu_score_1')
# Out:
# P01:	corpus_bleu_score_1: 0.005204298625351257 rouge_1: 0.0024322169059011163 rouge_l: 0.0024322169059011163
# M02:	corpus_bleu_score_1: 0.03922717146401357 rouge_1: 0.02753854332801701 rouge_l: 0.026182881446039336
# M04:	corpus_bleu_score_1: 0.030583719399508873 rouge_1: 0.011562998405103669 rouge_l: 0.01124401913875598
# M07:	corpus_bleu_score_1: 0.01571131110604795 rouge_1: 0.014486975013290802 rouge_l: 0.014486975013290802
# M15:	corpus_bleu_score_1: 0.01759132680185312 rouge_1: 0.003654970760233919 rouge_l: 0.003495481127060074
# corpus_bleu_score_1: 0.021663565479354958 rouge_1: 0.011935140882509306 rouge_l: 0.011568314726209462 valid_loss: 6.514905363596988
# P01:	corpus_bleu_score_1: 0.0042226779068884335 rouge_1: 0.0032961190855927695 rouge_l: 0.0032961190855927695
# M02:	dataset Pereira and parameters gpt2-xl_lr1e-5_tid1,2_a0.1f0.25_random missing user M02
# corpus_bleu_score_1: 0.0042226779068884335 rouge_1: 0.0032961190855927695 rouge_l: 0.0032961190855927695
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-4', dataset_name='HP', print_log=True,)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-4_random', dataset_name='HP', print_log=True,)
show_significance(result_1, result_2)
scatter_plot_comparation(result_1, result_2, metric = 'bert_scores')
scatter_plot_comparation(result_1, result_2, metric = 'corpus_bleu_score_1')
# plot_context_length2performance(result_1, result_2)
# plot_context_length2performance(result_1, result_2, metric = 'corpus_bleu_score_1')
# Out:
# F:	corpus_bleu_score_1: 0.14757524503426142 rouge_1: 0.12255009107468123 rouge_l: 0.12173041894353369
# I:	corpus_bleu_score_1: 0.14327131581229943 rouge_1: 0.11692167577413477 rouge_l: 0.11637522768670308
# J:	corpus_bleu_score_1: 0.14089426663197155 rouge_1: 0.11167577413479053 rouge_l: 0.1103096539162113
# H:	corpus_bleu_score_1: 0.1539058027582618 rouge_1: 0.12734061930783241 rouge_l: 0.1267941712204007
# K:	corpus_bleu_score_1: 0.149154740220314 rouge_1: 0.12395264116575591 rouge_l: 0.12367941712204006
# L:	corpus_bleu_score_1: 0.14956154046317982 rouge_1: 0.12460837887067394 rouge_l: 0.1232422586520947
# M:	corpus_bleu_score_1: 0.14843958712811173 rouge_1: 0.11916211293260473 rouge_l: 0.11861566484517304
# N:	corpus_bleu_score_1: 0.14702446005724695 rouge_1: 0.1170127504553734 rouge_l: 0.11673952641165755
# corpus_bleu_score_1: 0.1474783697632058 rouge_1: 0.12040300546448086 rouge_l: 0.11968579234972676 valid_loss: 3.5108512524698603
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_tid1,2_b2', dataset_name='Pereira', print_log=True,bert_metric=None)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_tid1,2_random_b2', dataset_name='Pereira', print_log=True,bert_metric=None)
show_significance(result_1, result_2)
# Out:
# P01:	corpus_bleu_score_1: 0.1963142857142857 rouge_1: 0.17606666666666665 rouge_l: 0.17173333333333335
# M02:	corpus_bleu_score_1: 0.1877126531878051 rouge_1: 0.1684666666666667 rouge_l: 0.163
# M04:	corpus_bleu_score_1: 0.2093095238095238 rouge_1: 0.19346666666666665 rouge_l: 0.18733333333333332
# M07:	corpus_bleu_score_1: 0.19700952380952377 rouge_1: 0.184 rouge_l: 0.17786666666666667
# M15:	corpus_bleu_score_1: 0.1854260085615004 rouge_1: 0.16046666666666667 rouge_l: 0.15766666666666668
# corpus_bleu_score_1: 0.19515439901652776 rouge_1: 0.17649333333333334 rouge_l: 0.17151999999999998 valid_loss: 3.6913856432914733
# P01:	corpus_bleu_score_1: 0.17915238095238095 rouge_1: 0.16686666666666666 rouge_l: 0.16446666666666665
# M02:	dataset Pereira and parameters gpt2-xl_lr1e-5_tid1,2_random_b2 missing user M02
# corpus_bleu_score_1: 0.17915238095238095 rouge_1: 0.16686666666666666 rouge_l: 0.16446666666666665
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2_lr1e-5_tid1,2_b2', dataset_name='Pereira', print_log=True,bert_metric=None)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2_lr1e-5_tid1,2_b2_random', dataset_name='Pereira', print_log=True,bert_metric=None)
show_significance(result_1, result_2)
# Out:
# P01:	corpus_bleu_score_1: 0.15727619047619046 rouge_1: 0.11853333333333334 rouge_l: 0.11706666666666667
# M02:	corpus_bleu_score_1: 0.16954761904761903 rouge_1: 0.13813333333333333 rouge_l: 0.13366666666666668
# M04:	corpus_bleu_score_1: 0.17789047619047618 rouge_1: 0.1382 rouge_l: 0.1346
# M07:	corpus_bleu_score_1: 0.16176666666666664 rouge_1: 0.11359999999999999 rouge_l: 0.11180000000000001
# M15:	corpus_bleu_score_1: 0.1623369371110911 rouge_1: 0.128 rouge_l: 0.12486666666666667
# corpus_bleu_score_1: 0.16576357789840868 rouge_1: 0.12729333333333331 rouge_l: 0.1244 valid_loss: 4.835722652435303
# P01:	corpus_bleu_score_1: 0.147 rouge_1: 0.1287333333333333 rouge_l: 0.12693333333333334
# M02:	dataset Pereira and parameters gpt2_lr1e-5_tid1,2_b2_random missing user M02
# corpus_bleu_score_1: 0.147 rouge_1: 0.1287333333333333 rouge_l: 0.12693333333333334
# M04:	dataset Pereira and parameters gpt2_lr1e-5_tid1,2_b2_random missing user M04
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-medium_lr1e-5_tid1,2_b2', dataset_name='Pereira', print_log=True,bert_metric=None)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-medium_lr1e-5_tid1,2_b2_random', dataset_name='Pereira', print_log=True,bert_metric=None)
show_significance(result_1, result_2)
# Out:
# P01:	corpus_bleu_score_1: 0.15993809523809524 rouge_1: 0.134 rouge_l: 0.134
# M02:	corpus_bleu_score_1: 0.19347619047619047 rouge_1: 0.1674666666666667 rouge_l: 0.16319999999999998
# M04:	corpus_bleu_score_1: 0.17455238095238093 rouge_1: 0.1436 rouge_l: 0.1426
# M07:	corpus_bleu_score_1: 0.1939142857142857 rouge_1: 0.16846666666666665 rouge_l: 0.16519999999999999
# M15:	corpus_bleu_score_1: 0.15034285714285717 rouge_1: 0.11639999999999999 rouge_l: 0.114
# corpus_bleu_score_1: 0.1744447619047619 rouge_1: 0.14598666666666668 rouge_l: 0.1438 valid_loss: 5.262439252185821
# P01:	corpus_bleu_score_1: 0.17232380952380952 rouge_1: 0.0906 rouge_l: 0.0888
# M02:	dataset Pereira and parameters gpt2-medium_lr1e-5_tid1,2_b2_random missing user M02
# corpus_bleu_score_1: 0.17232380952380952 rouge_1: 0.0906 rouge_l: 0.0888
# M04:	dataset Pereira and parameters gpt2-medium_lr1e-5_tid1,2_b2_random missing user M04
# corpus_bleu_score_1: 0.17232380952380952 rouge_1: 0.0906 rouge_l: 0.0888
# ...

# %%
# result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-large_lr1e-5_tid1,2_b2', dataset_name='Pereira', print_log=True,bert_metric=None)
# result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-large_lr1e-5_tid1,2_b2_random', dataset_name='Pereira', print_log=True,bert_metric=None)
# show_significance(result_1, result_2)

get_comparation_cases(result_1, result_2)
# Out:
# 113
# context:  People use bicycles for transportation,
# ground truth:  recreation and racing.
# brain+llm score 0.600: shopping, and recreation.
# llm score 0.000: as well asfor recreational purposes
# ------------------------------------------
# 363
# context:  People use bicycles for transportation,
# ground truth:  recreation and racing.
# brain+llm score 0.600: recreation, and leisure.
# llm score 0.000: as well asfor recreational purposes
# ------------------------------------------
# 613
# context:  People use bicycles for transportation,
# ground truth:  recreation and racing.
# brain+llm score 0.600: recreation, and leisure.
# llm score 0.000: as well asfor recreational purposes
# ------------------------------------------
# 863
# context:  People use bicycles for transportation,
# ground truth:  recreation and racing.
# brain+llm score 0.600: shopping, and recreation.
# llm score 0.000: as well asfor recreational purposes
# ------------------------------------------
# 936
# ...

# %%
from jupyter_utils import 
base_json = language_evaluate_mask_with_sig(result_1)
random_json = language_evaluate_mask_with_sig(result_2)

# %%
len(base_json['corpus_bleu_score'][1])
# Out:
# 1250

# %%
get_comparation_cases(result_2, result_1)
# Out:
# 0
# context:  Artisanal beekeepers go to extremes
# ground truth:  for their craft, but their
# brain+llm score 0.194: to ensure that their hives are healthy
# llm score 0.190: to protect their hives from pests and
# ------------------------------------------
# 1
# context:  Artisanal beekeepers go to extremes for their craft, but their
# ground truth:  product is worth the effort.
# brain+llm score 0.194: work is not for the faint of
# llm score 0.190: productsarecheap and widely available. Beekeepingisancient tradition
# ------------------------------------------
# 2
# context:  Artisanal honey-making emphasizes
# ground truth:  quality and character
# brain+llm score 0.194: the use of honeycomb
# llm score 0.190: the quality of the
# ------------------------------------------
# 3
# context:  Artisanal honey-making emphasizes quality and character
# ground truth:  over quantity and consistency.
# brain+llm score 0.194: . Honey is made from the
# ...

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained('/home/yzy/.cache/huggingface/hub/models--gpt2-xl/snapshots/33cdb5c0db5423c1879b1b9f16c352988e8754a8')

# %%
b = tokenizer.tokenize('hellothis is a good day')

# %%
tokenizer.tokenize('hello this is a good day')
# Out:
# ['hello', 'Ġthis', 'Ġis', 'Ġa', 'Ġgood', 'Ġday']

# %%
tokenizer.tokenize('hellothis is a good day')
# Out:
# ['hell', 'oth', 'is', 'Ġis', 'Ġa', 'Ġgood', 'Ġday']

# %%
tokenizer.convert_tokens_to_string(b, add_space_between_tokens=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 tokenizer.convert_tokens_to_string(b, add_space_between_tokens=True)
#
# TypeError: convert_tokens_to_string() got an unexpected keyword argument 'add_space_between_tokens'

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_b2_tid3', dataset_name='HP', print_log=True,bert_metric=None)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_b2_tid3_random', dataset_name='HP', print_log=True,bert_metric=None)
show_significance(result_1, result_2)
# Out:
# F:	corpus_bleu_score_1: 0.19250422846734325 rouge_1: 0.14380692167577414 rouge_l: 0.14312386156648452
# I:	corpus_bleu_score_1: 0.19978423974325613 rouge_1: 0.14216757741347905 rouge_l: 0.14182604735883425
# J:	corpus_bleu_score_1: 0.20527311562147632 rouge_1: 0.1568761384335155 rouge_l: 0.15551001821493626
# H:	corpus_bleu_score_1: 0.19466183103478185 rouge_1: 0.1381375227686703 rouge_l: 0.1377959927140255
# K:	corpus_bleu_score_1: 0.19559209385029055 rouge_1: 0.14448998178506375 rouge_l: 0.14380692167577414
# L:	corpus_bleu_score_1: 0.195619199410183 rouge_1: 0.13943533697632057 rouge_l: 0.13943533697632057
# M:	corpus_bleu_score_1: 0.18592787752623818 rouge_1: 0.1324453551912568 rouge_l: 0.1324453551912568
# N:	corpus_bleu_score_1: 0.16584428397952988 rouge_1: 0.10487249544626595 rouge_l: 0.10487249544626595
# corpus_bleu_score_1: 0.19190085870413737 rouge_1: 0.13777891621129323 rouge_l: 0.13735200364298725 valid_loss: 3.919210186258691
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_b2_tid3', dataset_name='HP', print_log=True,bert_metric=None)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_b2_tid3_random', dataset_name='HP', print_log=True,bert_metric=None)
show_significance(result_1, result_2)
# Out:
# F:	corpus_bleu_score_1: 0.19501691386937292 rouge_1: 0.13927595628415299 rouge_l: 0.1389344262295082
# I:	corpus_bleu_score_1: 0.19249338624338622 rouge_1: 0.13918488160291437 rouge_l: 0.13918488160291437
# J:	corpus_bleu_score_1: 0.18667165408968686 rouge_1: 0.13253642987249545 rouge_l: 0.13219489981785063
# H:	corpus_bleu_score_1: 0.19401966080008357 rouge_1: 0.13802367941712204 rouge_l: 0.13802367941712204
# K:	corpus_bleu_score_1: 0.19076296729985254 rouge_1: 0.14039162112932607 rouge_l: 0.14005009107468125
# L:	corpus_bleu_score_1: 0.19207541850984475 rouge_1: 0.13852459016393442 rouge_l: 0.13852459016393442
# M:	corpus_bleu_score_1: 0.17738528927053518 rouge_1: 0.12181238615664844 rouge_l: 0.12147085610200363
# N:	corpus_bleu_score_1: 0.1989781203920548 rouge_1: 0.14599271402550093 rouge_l: 0.14599271402550093
# corpus_bleu_score_1: 0.1909254263093521 rouge_1: 0.13696778233151186 rouge_l: 0.13679701730418944 valid_loss: 3.9239627710782763
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-large_lr1e-5_tid1,2_b2', dataset_name='Pereira', print_log=True,bert_metric=None)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-large_lr1e-5_tid1,2_b2_random', dataset_name='Pereira', print_log=True,bert_metric=None)
show_significance(result_1, result_2)

# get_comparation_cases(result_1, result_2)
# Out:
# P01:	corpus_bleu_score_1: 0.18941312758728157 rouge_1: 0.168 rouge_l: 0.16386666666666666
# M02:	corpus_bleu_score_1: 0.1862285714285714 rouge_1: 0.1672 rouge_l: 0.16440000000000002
# M04:	corpus_bleu_score_1: 0.18505076705779078 rouge_1: 0.17186666666666667 rouge_l: 0.16906666666666667
# M07:	corpus_bleu_score_1: 0.20260260365008143 rouge_1: 0.18106666666666665 rouge_l: 0.17613333333333334
# M15:	corpus_bleu_score_1: 0.1854333333333333 rouge_1: 0.1618666666666667 rouge_l: 0.15660000000000002
# corpus_bleu_score_1: 0.1897456806114117 rouge_1: 0.17 rouge_l: 0.16601333333333332 valid_loss: 3.9930649618148806
# P01:	corpus_bleu_score_1: 0.1938857142857143 rouge_1: 0.184 rouge_l: 0.1802
# M02:	dataset Pereira and parameters gpt2-large_lr1e-5_tid1,2_b2_random missing user M02
# corpus_bleu_score_1: 0.1938857142857143 rouge_1: 0.184 rouge_l: 0.1802
# M04:	dataset Pereira and parameters gpt2-large_lr1e-5_tid1,2_b2_random missing user M04
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_b2_tid3,4', dataset_name='ds003020', print_log=True,bert_metric=None)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_b2_tid3,4_random', dataset_name='ds003020', print_log=True,bert_metric=None)
show_significance(result_1, result_2)

# get_comparation_cases(result_1, result_2)
# Out:
# 4:	corpus_bleu_score_1: 0.14556621391425958 rouge_1: 0.16859144490124497 rouge_l: 0.16066587053511366
# corpus_bleu_score_1: 0.14556621391425958 rouge_1: 0.16859144490124497 rouge_l: 0.16066587053511366 valid_loss: 4.389172949458139
# 4:	corpus_bleu_score_1: 0.1455986164780465 rouge_1: 0.16923279401189076 rouge_l: 0.16069691197770455
# corpus_bleu_score_1: 0.1455986164780465 rouge_1: 0.16923279401189076 rouge_l: 0.16069691197770455 valid_loss: 4.406628970991752
# corpus_bleu_score_1: 0.14556621391425958,0.1455986164780465,0.981370599580222
# rouge_1: 0.16859144490124497, 0.16923279401189076, 0.7249148296496324
# rouge_l: 0.16066587053511366, 0.16069691197770455, 0.9859791154488295
# valid_loss: 4.389172949458139, 4.406628970991752, 2.476980615068124e-11
# bert_scores: nan, nan, nan
# bert_scores_part: nan, nan, nan

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-4_tid1,2_b2_layer12', dataset_name='Pereira', print_log=True,bert_metric=None)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-4_tid1,2_b2_layer12_random', dataset_name='Pereira', print_log=True,bert_metric=None)
show_significance(result_1, result_2)

# get_comparation_cases(result_1, result_2)
# Out:
# P01:	corpus_bleu_score_1: 0.07041573789416247 rouge_1: 0.06986666666666667 rouge_l: 0.06806666666666666
# M02:	corpus_bleu_score_1: 0.07190967292389945 rouge_1: 0.06513333333333332 rouge_l: 0.06513333333333332
# M04:	corpus_bleu_score_1: 0.04919047619047619 rouge_1: 0.037066666666666664 rouge_l: 0.037066666666666664
# M07:	corpus_bleu_score_1: 0.06834070554497618 rouge_1: 0.062266666666666665 rouge_l: 0.06146666666666666
# M15:	corpus_bleu_score_1: 0.08038754826984065 rouge_1: 0.07606666666666666 rouge_l: 0.07526666666666666
# corpus_bleu_score_1: 0.068048828164671 rouge_1: 0.062079999999999996 rouge_l: 0.0614 valid_loss: 6.714349160957337
# P01:	corpus_bleu_score_1: 0.1591 rouge_1: 0.143 rouge_l: 0.1402
# M02:	dataset Pereira and parameters gpt2-xl_lr1e-4_tid1,2_b2_layer12_random missing user M02
# corpus_bleu_score_1: 0.1591 rouge_1: 0.143 rouge_l: 0.1402
# M04:	dataset Pereira and parameters gpt2-xl_lr1e-4_tid1,2_b2_layer12_random missing user M04
# ...

# %%
result = get_results(base_path = '../results/', para_str='gpt2-xl_lr1e-5_tid1,2_b2_layer12_random', dataset_name = 'Pereira', u='', print_log = True, bert_metric=None,reload = False, file_name = 'test.json')
# Out:
# corpus_bleu_score_1: 0.20253333333333334 rouge_1: 0.20773333333333335 rouge_l: 0.20460000000000003

# %%
result['valid_loss']
# Out:
# {'valid_loss': [8.67958927154541,
#   8.373940467834473,
#   7.6406378746032715,
#   8.441832542419434,
#   8.811823844909668,
#   6.876046180725098,
#   7.4461517333984375,
#   8.21660327911377,
#   8.035073280334473,
#   8.147321701049805,
#   9.5762300491333,
#   6.846957206726074,
#   7.265885829925537,
#   7.838011741638184,
#   7.84014368057251,
#   9.324243545532227,
#   8.097804069519043,
#   7.521934509277344,
#   10.489287376403809,
#   7.238592624664307,
#   7.362786769866943,
#   8.81328010559082,
#   7.243113994598389,
#   7.1953125,
#   7.760341167449951,
#   6.464163780212402,
#   8.251543045043945,
#   7.74512243270874,
#   8.623345375061035,
#   8.853571891784668,
#   9.90597152709961,
#   8.237512588500977,
#   8.633498191833496,
#   6.67752742767334,
#   9.085589408874512,
#   7.5307135581970215,
#   9.537013053894043,
#   6.712684154510498,
#   8.083523750305176,
#   6.570450305938721,
#   7.989898681640625,
#   6.828873634338379,
#   8.467034339904785,
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'llama-7b_lr1e-5_tid1,2_b2', dataset_name='Pereira', print_log=True, bert_metric=None)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'llama-7b_lr1e-5_tid1,2_b2_random', dataset_name='Pereira', print_log=True, bert_metric=None)
show_significance(result_1, result_2)
# Out:
# P01:	corpus_bleu_score_1: 0.2753238095238095 rouge_1: 0.25647619047619047 rouge_l: 0.2498095238095238
# M02:	corpus_bleu_score_1: 0.26757619047619047 rouge_1: 0.27979999999999994 rouge_l: 0.2722
# M04:	corpus_bleu_score_1: 0.27625714285714287 rouge_1: 0.2601333333333333 rouge_l: 0.2513333333333333
# M07:	corpus_bleu_score_1: 0.2698666666666667 rouge_1: 0.28373333333333334 rouge_l: 0.27446666666666664
# M15:	corpus_bleu_score_1: 0.2674714285714285 rouge_1: 0.2742 rouge_l: 0.2666
# corpus_bleu_score_1: 0.2712990476190476 rouge_1: 0.27086857142857146 rouge_l: 0.26288190476190476 valid_loss: 2.1449787120223047
# P01:	corpus_bleu_score_1: 0.22065714285714286 rouge_1: 0.2343333333333333 rouge_l: 0.22846666666666668
# M02:	dataset Pereira and parameters llama-7b_lr1e-5_tid1,2_b2_random missing user M02
# corpus_bleu_score_1: 0.22065714285714286 rouge_1: 0.2343333333333333 rouge_l: 0.22846666666666668
# M04:	dataset Pereira and parameters llama-7b_lr1e-5_tid1,2_b2_random missing user M04
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_b2_tid3_pos', dataset_name='HP', print_log=True, bert_metric=None)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_b2_tid3_pos_random', dataset_name='HP', print_log=True, bert_metric=None)
show_significance(result_1, result_2)
# Out:
# F:	corpus_bleu_score_1: 0.19774373319455285 rouge_1: 0.13957194899817849 rouge_l: 0.1392304189435337
# I:	corpus_bleu_score_1: 0.19091963743603088 rouge_1: 0.13458561020036433 rouge_l: 0.13458561020036433
# J:	corpus_bleu_score_1: 0.1869671046925145 rouge_1: 0.1328551912568306 rouge_l: 0.1328551912568306
# H:	corpus_bleu_score_1: 0.19085187353629976 rouge_1: 0.13433515482695813 rouge_l: 0.1336520947176685
# K:	corpus_bleu_score_1: 0.19592440801457195 rouge_1: 0.14127959927140255 rouge_l: 0.14059653916211293
# L:	corpus_bleu_score_1: 0.19526845346517477 rouge_1: 0.13570127504553736 rouge_l: 0.13570127504553736
# M:

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_b2_pos', dataset_name='ds003020', print_log=True, bert_metric=None)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_b2_pos_random', dataset_name='ds003020', print_log=True, bert_metric=None)
show_significance(result_1, result_2)
# Out:
# 1:	corpus_bleu_score_1: 0.1472035847249492 rouge_1: 0.16651865755981982 rouge_l: 0.15595519626996626
# 2:	corpus_bleu_score_1: 0.15947071867346757 rouge_1: 0.18149068781635366 rouge_l: 0.17037419131850126
# 3:	corpus_bleu_score_1: 0.15245066322296455 rouge_1: 0.17156406614639058 rouge_l: 0.16081369195775977
# 4:	corpus_bleu_score_1: 0.15882578479432774 rouge_1: 0.18073804726347098 rouge_l: 0.17171525676368293
# 5:	corpus_bleu_score_1: 0.15313500197597904 rouge_1: 0.17651879328634776 rouge_l: 0.16663090071080383
# 6:	corpus_bleu_score_1: 0.1532509195057265 rouge_1: 0.1750805120357178 rouge_l: 0.16651076929527292
# 7:	corpus_bleu_score_1: 0.1466620382602741 rouge_1: 0.1642986183845748 rouge_l: 0.15454703354219093
# 8:	corpus_bleu_score_1: 0.1518363464334115 rouge_1: 0.17134452848738563 rouge_l: 0.16008025469284548
# corpus_bleu_score_1: 0.15285438219888753 rouge_1: 0.17344423887250762 rouge_l: 0.16332841181887794 valid_loss: 4.40502445620302
# ...

# %%
# result_1 = get_iterate_results(base_path = '../../history/decoding0907/results/', para_str = 'gpt2-xl_lr1e-5_tid1,2', dataset_name='Pereira', print_log=True, bert_metric=None)
# result_2 = get_iterate_results(base_path = '../../history/decoding0907/results/', para_str = 'gpt2-xl_lr1e-5_tid1,2_random', dataset_name='Pereira', print_log=True, bert_metric=None)
# show_significance(result_1, result_2)
plot_context_length2performance(result_1, result_2, metric='corpus_bleu_score_1')

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-large_lr1e-5_b4', dataset_name='Pereira', print_log=True, bert_metric=None,file_name='test_length.json')
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-large_lr1e-5_b4_random', dataset_name='Pereira', print_log=True, bert_metric=None,file_name='test_length.json')
# show_significance(result_1, result_2)
# plot_context_length2performance(result_1, result_2, metric='corpus_bleu_score_1')
plot_context_length2performance_all(result_1, result_2, metric='accuracy')

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-medium_lr1e-5_b4', dataset_name='HP', print_log=True, bert_metric=None)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-medium_lr1e-5_b4_random', dataset_name='HP', print_log=True, bert_metric=None)
show_significance(result_1, result_2)
# 漏加pos了...
# Out:
# F:	corpus_bleu_score_1: 0.0024134790528233152 rouge_1: 0.0024043715846994535 rouge_l: 0.0024043715846994535
# I:	corpus_bleu_score_1: 0.0023657732674126114 rouge_1: 0.002185792349726776 rouge_l: 0.002185792349726776
# J:	corpus_bleu_score_1: 0.0015313557116835806 rouge_1: 0.001366120218579235 rouge_l: 0.001366120218579235
# H:	corpus_bleu_score_1: 0.0013964784456587736 rouge_1: 0.001366120218579235 rouge_l: 0.001092896174863388
# K:	corpus_bleu_score_1: 0.0038589643507676297 rouge_1: 0.004007285974499089 rouge_l: 0.004007285974499089
# L:	corpus_bleu_score_1: 0.002167577413479053 rouge_1: 0.002185792349726776 rouge_l: 0.002185792349726776
# M:	corpus_bleu_score_1: 0.0033463440020817074 rouge_1: 0.0028233151183970854 rouge_l: 0.0028233151183970854
# N:	corpus_bleu_score_1: 0.001696591204787926 rouge_1: 0.0020036429872495446 rouge_l: 0.0020036429872495446
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-medium_lr1e-5_b4', dataset_name='Pereira', print_log=True, bert_metric=None)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-medium_lr1e-5_b4_random', dataset_name='Pereira', print_log=True, bert_metric=None)
show_significance(result_1, result_2)
# 漏加pos了...
# Out:
# P01:	corpus_bleu_score_1: 0.0024000000000000002 rouge_1: 0.002 rouge_l: 0.002
# M02:	corpus_bleu_score_1: 0.003980952380952381 rouge_1: 0.0057333333333333325 rouge_l: 0.0057333333333333325
# M04:	corpus_bleu_score_1: 0.003276190476190476 rouge_1: 0.004733333333333333 rouge_l: 0.004733333333333333
# M07:	corpus_bleu_score_1: 0.0019428571428571429 rouge_1: 0.0029333333333333334 rouge_l: 0.0029333333333333334
# M15:	corpus_bleu_score_1: 0.0013714285714285714 rouge_1: 0.0021333333333333334 rouge_l: 0.0021333333333333334
# corpus_bleu_score_1: 0.0025942857142857143 rouge_1: 0.003506666666666666 rouge_l: 0.003506666666666666 valid_loss: 73.42957449035644
# P01:	corpus_bleu_score_1: 0.004742857142857143 rouge_1: 0.0036 rouge_l: 0.0036
# M02:	dataset Pereira and parameters gpt2-medium_lr1e-5_b4_random missing user M02
# corpus_bleu_score_1: 0.004742857142857143 rouge_1: 0.0036 rouge_l: 0.0036
# M04:	dataset Pereira and parameters gpt2-medium_lr1e-5_b4_random missing user M04
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-large_lr1e-5_b4', dataset_name='Pereira', print_log=True, bert_metric=None)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-large_lr1e-5_b4_random', dataset_name='Pereira', print_log=True, bert_metric=None)
show_significance(result_1, result_2)
# 漏加pos了...
# Out:
# P01:	corpus_bleu_score_1: 0.10471904761904761 rouge_1: 0.09273333333333333 rouge_l: 0.09113333333333333
# M02:	corpus_bleu_score_1: 0.09133809523809523 rouge_1: 0.08166666666666667 rouge_l: 0.08066666666666668
# M04:	corpus_bleu_score_1: 0.0917904761904762 rouge_1: 0.0726 rouge_l: 0.0726
# M07:	corpus_bleu_score_1: 0.0887031746031746 rouge_1: 0.07406666666666667 rouge_l: 0.07326666666666666
# M15:	corpus_bleu_score_1: 0.09217142857142856 rouge_1: 0.08686666666666668 rouge_l: 0.08606666666666667
# corpus_bleu_score_1: 0.09374444444444445 rouge_1: 0.08158666666666665 rouge_l: 0.08074666666666667 valid_loss: 5.193715355491638
# P01:	corpus_bleu_score_1: 0.14713809523809523 rouge_1: 0.11366666666666665 rouge_l: 0.11186666666666667
# M02:	dataset Pereira and parameters gpt2-large_lr1e-5_b4_random missing user M02
# corpus_bleu_score_1: 0.14713809523809523 rouge_1: 0.11366666666666665 rouge_l: 0.11186666666666667
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_b4_pos', dataset_name='Pereira', print_log=True, bert_metric=None)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-xl_lr1e-5_b4_pos_random', dataset_name='Pereira', print_log=True, bert_metric=None)
show_significance(result_1, result_2)
# 漏加pos了...
# Out:
# P01:	corpus_bleu_score_1: 0.15751428571428575 rouge_1: 0.15086666666666668 rouge_l: 0.1492
# M02:	corpus_bleu_score_1: 0.14484761904761906 rouge_1: 0.14346666666666663 rouge_l: 0.1418
# M04:	corpus_bleu_score_1: 0.12377619047619047 rouge_1: 0.12533333333333335 rouge_l: 0.11926666666666665
# M07:	corpus_bleu_score_1: 0.13852857142857142 rouge_1: 0.14006666666666667 rouge_l: 0.1376
# M15:	corpus_bleu_score_1: 0.1132 rouge_1: 0.11633333333333333 rouge_l: 0.11353333333333333
# corpus_bleu_score_1: 0.13557333333333332 rouge_1: 0.13521333333333335 rouge_l: 0.13228 valid_loss: 3.9128539695739746
# P01:	dataset Pereira and parameters gpt2-xl_lr1e-5_b4_pos_random missing user P01
# dataset Pereira and parameters gpt2-xl_lr1e-5_b4_pos_random missing user P01
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [91], in <cell line: 2>()
# ...

# %%
result_1 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-medium_lr1e-5_b4', dataset_name='Pereira', print_log=True, bert_metric=None)
result_2 = get_iterate_results(base_path = '../results/', para_str = 'gpt2-medium_lr1e-5_b4_random', dataset_name='Pereira', print_log=True, bert_metric=None)
show_significance(result_1, result_2)
# 漏加pos了...
# Out:
# P01:	corpus_bleu_score_1: 0.20565714285714284 rouge_1: 0.18933333333333333 rouge_l: 0.18753333333333333
# M02:	corpus_bleu_score_1: 0.16598095238095237 rouge_1: 0.15266666666666664 rouge_l: 0.14806666666666665
# M04:	corpus_bleu_score_1: 0.17519047619047617 rouge_1: 0.16240000000000002 rouge_l: 0.1568
# M07:	corpus_bleu_score_1: 0.11265714285714286 rouge_1: 0.07786666666666667 rouge_l: 0.07706666666666666
# M15:	corpus_bleu_score_1: 0.18140476190476187 rouge_1: 0.15473333333333336 rouge_l: 0.15393333333333334
# corpus_bleu_score_1: 0.16817809523809524 rouge_1: 0.1474 rouge_l: 0.14468000000000003 valid_loss: 3.6462420838832856
# P01:	corpus_bleu_score_1: 0.11746666666666666 rouge_1: 0.08786666666666666 rouge_l: 0.08786666666666666
# M02:	dataset Pereira and parameters gpt2-medium_lr1e-5_b4_random missing user M02
# corpus_bleu_score_1: 0.11746666666666666 rouge_1: 0.08786666666666666 rouge_l: 0.08786666666666666
# ...

# %%
user_list = ['F','I','J','H',]
result_1 = get_iterate_results(base_path = '../../history/decoding0918/results/', para_str = 'llama-7b_lr1e-5_b2_tid3_pos', dataset_name='HP', print_log=True, bert_metric=None,user_list=user_list)
result_2 = get_iterate_results(base_path = '../../history/decoding0918/results/', para_str = 'llama-7b_lr1e-5_b2_tid3_pos_random', dataset_name='HP', print_log=True, bert_metric=None,user_list=user_list)
show_significance(result_1, result_2)
# 漏加pos了...
# Out:
# F:	corpus_bleu_score_1: 0.2278113886720444 rouge_1: 0.17775500910746808 rouge_l: 0.17775500910746808
# I:	corpus_bleu_score_1: 0.23424787492410443 rouge_1: 0.18303734061930785 rouge_l: 0.18269581056466305
# J:	corpus_bleu_score_1: 0.22584189869025934 rouge_1: 0.17607012750455373 rouge_l: 0.1757285974499089
# H:	corpus_bleu_score_1: 0.2192430630961087 rouge_1: 0.16534608378870674 rouge_l: 0.16466302367941713
# corpus_bleu_score_1: 0.2267860563456292 rouge_1: 0.1755521402550091 rouge_l: 0.1752106102003643 valid_loss: 2.406697795914659
# F:	dataset HP and parameters llama-7b_lr1e-5_b2_tid3_pos_random missing user F
# dataset HP and parameters llama-7b_lr1e-5_b2_tid3_pos_random missing user F
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [105], in <cell line: 3>()
#       1 user_list = ['F','I','J','H',]
# ...
